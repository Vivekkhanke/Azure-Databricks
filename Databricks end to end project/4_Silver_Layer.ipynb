# %% [markdown]
# ## **DLT - Delta Live Table**
# We can create 3 things in DLT
#
# - Streaming table
# - Mat Views - Static table
# - Views - or streaming view as well

# %%
df = spark.read.format("delta")\
    .load("/Volumes/workspace/bronze/bronzevolume/bookings/data/")

display(df)

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
# Added modified_date column to track when the record was modified or updated.

df = df.withColumn("amount", col("amount").cast(DoubleType()))\
    .withColumn("modified_date", current_timestamp())\
    .withColumn("booking_date", to_date(col("booking_date")))\
    .drop("_rescued_data") 
df.display()

# %%
import dlt
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
df_stream = spark.readStream.format("delta")\
    .load("/Volumes/workspace/bronze/bronzevolume/bookings/data/")
